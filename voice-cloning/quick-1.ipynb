# %%
# this is the Text-to-speech (TTS) library
# !pip install TTS==0.21.3
# Out:
# Requirement already satisfied: TTS==0.21.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (0.21.3)
# Requirement already satisfied: cython>=0.29.30 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (3.0.10)
# Requirement already satisfied: scipy>=1.11.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (1.14.0)
# Requirement already satisfied: torch>=2.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (2.4.0)
# Requirement already satisfied: torchaudio in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (2.4.0)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.12.1)
# Requirement already satisfied: librosa>=0.10.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.10.2.post1)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (1.5.1)
# Requirement already satisfied: inflect>=5.6.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (7.3.1)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (4.66.4)
# Requirement already satisfied: anyascii>=0.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (6.0.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (2024.5.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (3.9.5)
# Requirement already satisfied: packaging>=23.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (24.1)
# Requirement already satisfied: flask>=2.0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (3.0.3)
# Requirement already satisfied: pysbd>=0.3.4 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.5.6)
# Requirement already satisfied: pandas<2.0,>=1.4 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (3.7.1)
# Requirement already satisfied: trainer>=0.0.32 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.0.17)
# Requirement already satisfied: jieba in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.42.1)
# Requirement already satisfied: pypinyin in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.51.0)
# Requirement already satisfied: hangul-romanize in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.2.3)
# Requirement already satisfied: jamo in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.4.1)
# Requirement already satisfied: nltk in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (3.8.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.1.2)
# Requirement already satisfied: bangla in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.0.2)
# Requirement already satisfied: bnnumerizer in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.8.0)
# Requirement already satisfied: transformers>=4.33.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (4.43.2)
# Requirement already satisfied: encodec>=0.1.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (1.3.8)
# Requirement already satisfied: num2words in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.5.13)
# Requirement already satisfied: spacy>=3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy[ja]>=3->TTS==0.21.3) (3.7.5)
# Requirement already satisfied: numpy>=1.24.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (1.26.4)
# Requirement already satisfied: numba>=0.57.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from TTS==0.21.3) (0.60.0)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.15.0)
# Requirement already satisfied: dateparser~=1.1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (0.9.10)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.0.1)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from gruut[de,es,fr]==2.2.3->TTS==0.21.3) (2.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS==0.21.3) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS==0.21.3) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS==0.21.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS==0.21.3) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from aiohttp>=3.8.1->TTS==0.21.3) (1.9.4)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from flask>=2.0.1->TTS==0.21.3) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from flask>=2.0.1->TTS==0.21.3) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from flask>=2.0.1->TTS==0.21.3) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from flask>=2.0.1->TTS==0.21.3) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from flask>=2.0.1->TTS==0.21.3) (1.8.2)
# Requirement already satisfied: more-itertools>=8.5.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from inflect>=5.6.0->TTS==0.21.3) (10.3.0)
# Requirement already satisfied: typeguard>=4.0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from inflect>=5.6.0->TTS==0.21.3) (4.3.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (0.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from librosa>=0.10.0->TTS==0.21.3) (1.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from matplotlib>=3.7.0->TTS==0.21.3) (2.9.0.post0)
# Requirement already satisfied: docopt>=0.6.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from num2words->TTS==0.21.3) (0.6.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from numba>=0.57.0->TTS==0.21.3) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pandas<2.0,>=1.4->TTS==0.21.3) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from scikit-learn>=1.3.0->TTS==0.21.3) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from soundfile>=0.12.0->TTS==0.21.3) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.8.2)
# Requirement already satisfied: setuptools in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.4.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy[ja]>=3->TTS==0.21.3) (0.6.8)
# Requirement already satisfied: sudachidict-core>=20211220 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from spacy[ja]>=3->TTS==0.21.3) (20240716)
# Requirement already satisfied: filelock in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from torch>=2.1->TTS==0.21.3) (3.15.4)
# Requirement already satisfied: sympy in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from torch>=2.1->TTS==0.21.3) (1.13.1)
# Requirement already satisfied: psutil in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from trainer>=0.0.32->TTS==0.21.3) (6.0.0)
# Requirement already satisfied: tensorboard in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from trainer>=0.0.32->TTS==0.21.3) (2.15.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from transformers>=4.33.0->TTS==0.21.3) (0.24.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from transformers>=4.33.0->TTS==0.21.3) (2024.7.24)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from transformers>=4.33.0->TTS==0.21.3) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from transformers>=4.33.0->TTS==0.21.3) (0.4.3)
# Requirement already satisfied: pynndescent>=0.5 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from umap-learn>=0.5.1->TTS==0.21.3) (0.5.13)
# Requirement already satisfied: pycparser in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.0->TTS==0.21.3) (2.22)
# Requirement already satisfied: tzlocal in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from Jinja2>=3.1.2->flask>=2.0.1->TTS==0.21.3) (2.1.5)
# Requirement already satisfied: six in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.21.3) (1.16.0)
# Requirement already satisfied: language-data>=1.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.2.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pooch>=1.1->librosa>=0.10.0->TTS==0.21.3) (4.2.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (7.0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from sympy->torch>=2.1->TTS==0.21.3) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (2.32.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (4.25.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->TTS==0.21.3) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS==0.21.3) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS==0.21.3) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS==0.21.3) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->TTS==0.21.3) (2.0.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (2.18.0)
# Requirement already satisfied: wrapt in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.21.3) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->TTS==0.21.3) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->TTS==0.21.3) (3.2.2)

# %%
#import torch
#torch.__version__

# %%
# This is needed only if you want to play the .wav files in the notebook
from IPython.display import Audio

# %%
#device = 'mps'
device = 'cpu'

# %%
from TTS.api import TTS

# Check available models
#print("\n".join(TTS().list_models()))

# %%
#init TTS with the xtts2 model
#model_name = 'tts_models/multilingual/multi-dataset/xtts_v2'
model_name = TTS().list_models()[0]

tts = TTS(model_name).to(device)
# Out:
# No API token found for 🐸Coqui Studio voices - https://coqui.ai
# Visit 🔗https://app.coqui.ai/account to get one.
# Set it as an environment variable `export COQUI_STUDIO_TOKEN=<token>`
#
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# /Users/dsezer/.pyenv/versions/3.11.3/lib/python3.11/site-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)

# %%
# The input file that I recorded
AUDIO_INPUT = 'inputs/test1.wav'

# The file where the output will be written at the end
AUDIO_OUTPUT = 'outputs/test.wav'

# %%
# You can listen to the file I recorded
Audio(AUDIO_INPUT, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# The text that I am supposed to read at the end
TEXT = 'Once upon a time a little girl lived in Heidelberg. She was friends with the wolf and everyone loved her.'

# %%
# Now TTS generates a sound file of this text with my voice
tts.tts_to_file(text=TEXT,
                speaker_wav=AUDIO_INPUT,
                language='en',
                file_path=AUDIO_OUTPUT)
# Out:
#  > Text splitted to sentences.
# ['Once upon a time a little girl lived in Heidelberg.', 'She was friends with the wolf and everyone loved her.']
#  > Processing time: 15.185861349105835
#  > Real-time factor: 1.7817142151997685
# 'outputs/test.wav'

# %%
# Here is how the result sounds
Audio(AUDIO_OUTPUT, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
